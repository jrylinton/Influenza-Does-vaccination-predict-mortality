# %%
import pandas as pd

# %%
file_csv="National_Custom_Data.csv"

mortality_df=pd.read_csv(file_csv)

# %%
mortality_df.head(15)
# Out:
#         AREA  SUB AREA AGE GROUP   SEASON  WEEK  THRESHOLD  BASELINE  \
# 0   National       NaN       All  2019-20    40        5.7       5.3
# 1   National       NaN       All  2019-20    41        5.7       5.4
# 2   National       NaN       All  2019-20    42        5.8       5.5
# 3   National       NaN       All  2019-20    43        5.9       5.6
# 4   National       NaN       All  2019-20    44        6.0       5.7
# 5   National       NaN       All  2019-20    45        6.2       5.8
# 6   National       NaN       All  2019-20    46        6.3       5.9
# 7   National       NaN       All  2019-20    47        6.4       6.0
# 8   National       NaN       All  2019-20    48        6.5       6.2
# 9   National       NaN       All  2019-20    49        6.6       6.3
# 10  National       NaN       All  2019-20    50        6.7       6.4
# 11  National       NaN       All  2019-20    51        6.8       6.5
# 12  National       NaN       All  2019-20    52        6.9       6.6
# ...

# %%
mortality_df2=mortality_df.drop(columns=["AGE GROUP","AREA","SUB AREA","THRESHOLD","BASELINE","PERCENT P&I","PERCENT COMPLETE"])

# %%
mortality_df2.head()
# Out:
#     SEASON  WEEK NUM INFLUENZA DEATHS NUM PNEUMONIA DEATHS TOTAL DEATHS
# 0  2019-20    40                   16                2,698       52,442
# 1  2019-20    41                   16                2,766       52,850
# 2  2019-20    42                   18                2,976       54,108
# 3  2019-20    43                   30                2,983       53,896
# 4  2019-20    44                   31                2,904       53,953

# %%
mortality_json=mortality_df2.to_json("mortality_df.json")
